# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Ingredients.csv')

# %%
df
# Out:
#     sweetness  crunchiness ingredients      class
# 0           1            1      cheese    protein
# 1           3            1        fish    protein
# 2           2            2      shrimp    protein
# 3           1            4       bacon    protein
# 4           3            5        nuts    protein
# 5           1            9     lettuce  vegetable
# 6           2            8    cucumber  vegetable
# 7           3            7  green bean  vegetable
# 8           5           10      carrot  vegetable
# 9           3           10      celery  vegetable
# 10         10            9       apple      fruit
# 11         10            7        pear      fruit
# 12          9            5       grape      fruit
# 13          9            2      orange      fruit
# 14         10            2      banana      fruit

# %%
sns.set(style="whitegrid")
sns.jointplot(
    data=df,
    x="sweetness",
    y="crunchiness",
    hue="class",
    kind="scatter",
    palette="Set2"
);

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.columns
# Out:
# Index(['sweetness', 'crunchiness', 'ingredients', 'class'], dtype='object')

# %%
# separate the input and output

x = df[['sweetness', 'crunchiness']]
y = df['class']

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
knn.fit(x, y)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
"""
sweetness = 6
crunchiness = 4
"""
# Out:
# '\nsweetness = 6\ncrunchiness = 4\n'

# %%
newdf = pd.DataFrame({
    'sweetness': [6],
    'crunchiness': [4]
})

# %%
newdf
# Out:
#    sweetness  crunchiness
# 0          6            4

# %%
pred = knn.predict(newdf)

# %%
pred_class
# Out:
# array(['fruit'], dtype=object)
