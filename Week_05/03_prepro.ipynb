# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
en_df=pd.get_dummies(df, columns = ['sex', 'embarked', 'class'],
                    drop_first = True)

# %%
en_df
# Out:
#      survived  pclass   age  sibsp  parch     fare    who  adult_male deck  \
# 0           0       3  22.0      1      0   7.2500    man        True  NaN
# 1           1       1  38.0      1      0  71.2833  woman       False    C
# 2           1       3  26.0      0      0   7.9250  woman       False  NaN
# 3           1       1  35.0      1      0  53.1000  woman       False    C
# 4           0       3  35.0      0      0   8.0500    man        True  NaN
# ..        ...     ...   ...    ...    ...      ...    ...         ...  ...
# 886         0       2  27.0      0      0  13.0000    man        True  NaN
# 887         1       1  19.0      0      0  30.0000  woman       False    B
# 888         0       3   NaN      1      2  23.4500  woman       False  NaN
# 889         1       1  26.0      0      0  30.0000    man        True    C
# 890         0       3  32.0      0      0   7.7500    man        True  NaN
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
en_df['who'] = le.fit_transform(en_df['who'])

# %%
en_df
# Out:
#      survived  pclass   age  sibsp  parch     fare  who  adult_male deck  \
# 0           0       3  22.0      1      0   7.2500    1        True  NaN
# 1           1       1  38.0      1      0  71.2833    2       False    C
# 2           1       3  26.0      0      0   7.9250    2       False  NaN
# 3           1       1  35.0      1      0  53.1000    2       False    C
# 4           0       3  35.0      0      0   8.0500    1        True  NaN
# ..        ...     ...   ...    ...    ...      ...  ...         ...  ...
# 886         0       2  27.0      0      0  13.0000    1        True  NaN
# 887         1       1  19.0      0      0  30.0000    2       False    B
# 888         0       3   NaN      1      2  23.4500    2       False  NaN
# 889         1       1  26.0      0      0  30.0000    1        True    C
# 890         0       3  32.0      0      0   7.7500    1        True  NaN
#
#      embark_town alive  alone  sex_male  embarked_Q  embarked_S  class_Second  \
# ...

# %% [markdown]
# # binning and descriptization

# %%
en_df['age'] = pd.cut(df['age'],bins = [0, 18, 50, 100],
                     labels= ['child', 'adult','senoir'])

# %%
en_df
# Out:
#      survived  pclass    age  sibsp  parch     fare  who  adult_male deck  \
# 0           0       3  adult      1      0   7.2500    1        True  NaN
# 1           1       1  adult      1      0  71.2833    2       False    C
# 2           1       3  adult      0      0   7.9250    2       False  NaN
# 3           1       1  adult      1      0  53.1000    2       False    C
# 4           0       3  adult      0      0   8.0500    1        True  NaN
# ..        ...     ...    ...    ...    ...      ...  ...         ...  ...
# 886         0       2  adult      0      0  13.0000    1        True  NaN
# 887         1       1  adult      0      0  30.0000    2       False    B
# 888         0       3    NaN      1      2  23.4500    2       False  NaN
# 889         1       1  adult      0      0  30.0000    1        True    C
# 890         0       3  adult      0      0   7.7500    1        True  NaN
#
#      embark_town alive  alone  sex_male  embarked_Q  embarked_S  class_Second  \
# ...

# %%
en_df['age'].value_counts()
# Out:
# age
# adult     511
# child     139
# senoir     64
# Name: count, dtype: int64

# %% [markdown]
# # z score for outlier

# %%
from scipy.stats import zscore

# %%
fare_clean = df['fare'].dropna()
z = np.abs(zscore(fare_clean))

# %%
print("zscore ol", (z > 3).sum())
# Out:
# zscore ol 20

# %%
z
# Out:
# array([5.02445171e-01, 7.86845294e-01, 4.88854258e-01, 4.20730236e-01,
#        4.86337422e-01, 4.78116429e-01, 3.95813561e-01, 2.24083121e-01,
#        4.24256141e-01, 4.29555021e-02, 3.12172378e-01, 1.13845709e-01,
#        4.86337422e-01, 1.87093118e-02, 4.90279793e-01, 3.26266659e-01,
#        6.19988892e-02, 3.86670720e-01, 2.85997284e-01, 5.02948539e-01,
#        1.24919787e-01, 3.86670720e-01, 4.86756223e-01, 6.63597416e-02,
#        2.24083121e-01, 1.64441595e-02, 5.02948539e-01, 4.64700108e+00,
#        4.89776426e-01, 4.89442190e-01, 9.02720170e-02, 2.30172882e+00,
#        4.92377828e-01, 4.37007438e-01, 1.00606170e+00, 3.98582080e-01,
#        5.02863973e-01, 4.86337422e-01, 2.85997284e-01, 4.22073541e-01,
#        4.57645492e-01, 2.25593223e-01, 4.89442190e-01, 1.88762532e-01,
#        4.89776426e-01, 4.86337422e-01, 3.36334002e-01, 4.92377828e-01,
#        2.11917743e-01, 2.90024222e-01, 1.50673744e-01, 4.91371093e-01,
# ...
