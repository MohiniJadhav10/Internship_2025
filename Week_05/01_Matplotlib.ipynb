# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([12, 23, 32, 37, 44, 49, 51, 56, 59, 64])
y = np.array([10, 14, 19, 25, 30, 35, 40, 43, 51, 59])
z = np.array([70, 65, 61, 58, 50, 48, 42, 37, 28, 15])

# %% [markdown]
# # line plot

# %%
plt.title("line plot")
plt.xlabel("x values")
plt.ylabel("y values")

plt.plot(x, y, color = 'magenta', marker = '*', mfc = 'black', ls = '--');
plt.grid()
#markes => <,>,^,H,o,*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([12, 23, 32, 37, 44, 49, 51, 56, 59, 64])
y = np.array([10, 14, 19, 25, 30, 35, 40, 43, 51, 59])
z = np.array([70, 65, 61, 58, 50, 48, 42, 37, 28, 15])

# %%
plt.figure(figsize=(16,9))
plt.subplot(2, 2, 1)
plt.title("line plot")
plt.xlabel("x values")
plt.ylabel("y values")

plt.plot(x, y, color = 'magenta', marker = '*', mfc = 'black', ls = '--');
plt.grid()
plt.subplot(2, 2, 2)
plt.title("line plot")
plt.xlabel("x values")
plt.ylabel("z values")

plt.plot(x, z, color = 'blue', marker = '*', mfc = 'red', ls = '--');
plt.grid()

# %% [markdown]
# # Bar Graph

# %%
courses = ['python', 'dart', 'php', 'ruby', 'c++']
students = [56, 40, 30, 41, 65]

# %%
plt.title('student enrollment')
plt.xlabel('courses')
plt.ylabel('no. of students')
plt.bar(courses, students, color = 'purple', width = 0.5, edgecolor = 'yellow' );
plt.grid()

# %%
# load the student.csv
# plot marks by students name bar graph

# %%
df = pd.read_csv('student.csv')

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
plt.title('student marks')
plt.xlabel(' student name ')
plt.ylabel('marks')
plt.bar(df. name, df.marks, color = 'yellow', width = 0.5, edgecolor = 'black' );

# %%
# data => Social_Network_Ads.csv
# plto the bar graph to chcek how many people purchased the product and how many not

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510    Male  19.0          19000.0          0
# 1  15810944    Male  35.0          20000.0          0
# 2  15668575  Female  26.0          43000.0          0
# 3  15603246  Female  27.0          57000.0          0
# 4  15804002    Male  19.0          76000.0          0

# %%
df['Purchased'].value_counts().index
# Out:
# Index([0, 1], dtype='int64', name='Purchased')

# %%
plt.xticks(range(0, 2, 1))
plt.bar(df['Purchased'].value_counts().index,
        df['Purchased'].value_counts());

# %% [markdown]
# # Histogram

# %%
data = np.random.randn(1000)

# %%
data
# Out:
# array([-1.24515565e+00,  1.74548913e-01, -7.08740535e-01,  6.83598930e-01,
#        -1.82820449e-01, -1.79640541e-01, -7.60897016e-01, -1.58803158e+00,
#         3.00262908e+00, -1.32082481e+00,  4.31866428e-01,  7.32956372e-01,
#        -3.42895726e-01,  1.14172628e+00, -4.03286954e-01, -1.77731525e+00,
#        -5.25584051e-01, -7.50847700e-01,  1.63365602e-01, -2.06967173e+00,
#        -7.03339097e-01,  7.46198305e-01,  2.01025720e+00, -5.96698056e-01,
#        -8.74867628e-01,  1.02281560e+00,  9.96694837e-01,  1.60811284e+00,
#         6.07118211e-01,  2.17079957e-02, -1.08718708e+00, -2.86084142e-01,
#        -2.27260686e-01, -7.23108492e-01, -1.00313726e+00,  1.35390342e-01,
#        -7.01390410e-01,  1.50300653e-02,  6.78376770e-01,  1.67170433e+00,
#         8.32582612e-01, -3.19114962e-01, -6.64769960e-01, -1.06657592e+00,
#         7.19934291e-01, -2.21306064e+00, -7.24141409e-01,  8.55601956e-01,
# ...

# %%
plt.figure(figsize = (16, 9))
plt.hist(data, bins = 30)
plt.grid()

# %% [markdown]
# # Scatter plot

# %%
x = np.array([12, 23, 32, 37, 44, 49, 51, 56, 59, 64])
y = np.array([10, 14, 19, 25, 30, 35, 40, 43, 51, 59])
z = np.array([70, 65, 61, 58, 50, 48, 42, 37, 28, 15])

# %%
plt.scatter(x, y, marker = '*');
plt.grid()

# %% [markdown]
# # pie chart

# %%
courses
# Out:
# ['python', 'dart', 'php', 'ruby', 'c++']

# %%
students
# Out:
# [56, 40, 30, 41, 65]

# %%
plt.pie(students, labels= courses, autopct ="%.2f%%",
       explode = [0.2, 0, 0 ,0 ,0]);

# %%
# take any four plots from above and and put them in same figure(subplot)

# %%
# Data
courses = ['python', 'dart', 'php', 'ruby', 'c++']
students = [56, 40, 30, 41, 65]
plt.figure(figsize=(12, 9))

# 1. Line Plot
plt.subplot(2, 2, 1)
plt.plot(courses, students, marker='o', color='blue')
plt.title("Line Plot")
plt.xlabel("Courses")
plt.ylabel("Students")

# 2. Bar Plot
plt.subplot(2, 2, 2)
plt.bar(courses, students, color='green')
plt.title("Bar Plot")
plt.xlabel("Courses")
plt.ylabel("Students")

# 3. Scatter Plot
plt.subplot(2, 2, 3)
plt.scatter(courses, students, color='red')
plt.title("Scatter Plot")
plt.xlabel("Courses")
plt.ylabel("Students")

# 4. Pie Chart
plt.subplot(2, 2, 4)
plt.pie(students, labels=courses, autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart")

plt.savefig('my_plot.png')

# %% [markdown]
# # Practice questions

# %%
df = pd.read_csv('train (1).csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#question1

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(6, 4))
plt.plot(df['PassengerId'][:10], df['Fare'][:10], marker='o', linestyle='-', color='blue')
plt.title("Fare of First 10 Passengers")
plt.xlabel("Passenger ID")
plt.ylabel("Fare")
plt.grid()

# %%
#question 2

pclass_counts = df['Pclass'].value_counts().sort_index()

plt.figure(figsize=(6, 4))
plt.bar(pclass_counts.index.astype(str), pclass_counts.values, color='orange')
plt.title("Number of Passengers by Class")
plt.xlabel("Pclass")
plt.ylabel("Passenger Count")
plt.grid()

# %%
#question3 

plt.figure(figsize=(8, 5))
plt.hist(df.Age , bins=20, color='teal', edgecolor='black')
plt.title("Distribution of Passenger Ages")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.grid()

# %%
#question4
